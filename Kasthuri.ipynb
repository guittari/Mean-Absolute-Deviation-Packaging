# %%
#creating data metrics for:  Kasthuri

# %%
#Kasthuri Mouse Data Metrics:

# %%
import networkx as nx
import numpy as np

# %%
# pip install numpy tifffile cloud-volume
import numpy as np
import tifffile
from cloudvolume import CloudVolume

vol = CloudVolume(
    "s3://open-neurodata/kasthuri/kasthuri11/image", mip=0, use_https=True
)

# load data into numpy array
cutout = vol[11264:11776, 13312:13824, 912:928]

# save cutout as TIFF
tifffile.imwrite("data.tiff", data=np.transpose(cutout))
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]

# %%
# pip install numpy tifffile cloud-volume
import numpy as np
import tifffile
from cloudvolume import CloudVolume

vol = CloudVolume(
    "s3://open-neurodata/kasthuri/kasthuri11/image", mip=0, use_https=True
)

# load data into numpy array
cutout = vol[11264:11776, 13312:13824, 912:928]

# save cutout as TIFF
tifffile.imwrite("data.tiff", data=np.transpose(cutout))
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]

# %%
# pip install numpy tifffile cloud-volume
import numpy as np
import tifffile
from cloudvolume import CloudVolume

vol = CloudVolume(
    "s3://open-neurodata/kasthuri/kasthuri14Maine/image", mip=0, use_https=True
)

# load data into numpy array
cutout = vol[2560:3072, 3072:3584, 1184:1200]

# save cutout as TIFF
tifffile.imwrite("data.tiff", data=np.transpose(cutout))
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]

# %%
#kasthuri data imported from neurodata
graph = nx.read_graphml("/Users/circuiteer/Downloads/kasthuri_graph_v4.graphml")

# %%
graph

# %%
graph.degree()
# Out:
# DiMultiDegreeView({'n0': 61, 'n1': 5, 'n2': 10, 'n3': 4, 'n4': 15, 'n5': 2, 'n6': 153, 'n7': 2, 'n8': 4, 'n9': 3, 'n10': 22, 'n11': 2, 'n12': 8, 'n13': 1, 'n14': 34, 'n15': 1, 'n16': 9, 'n17': 2, 'n18': 21, 'n19': 2, 'n20': 12, 'n21': 4, 'n22': 13, 'n23': 9, 'n24': 3, 'n25': 3, 'n26': 17, 'n27': 1, 'n28': 14, 'n29': 2, 'n30': 9, 'n31': 2, 'n32': 16, 'n33': 5, 'n34': 2, 'n35': 45, 'n36': 3, 'n37': 26, 'n38': 2, 'n39': 2, 'n40': 1, 'n41': 16, 'n42': 4, 'n43': 1, 'n44': 4, 'n45': 1, 'n46': 5, 'n47': 2, 'n48': 3, 'n49': 6, 'n50': 1, 'n51': 7, 'n52': 1, 'n53': 2, 'n54': 10, 'n55': 13, 'n56': 1, 'n57': 2, 'n58': 1, 'n59': 2, 'n60': 3, 'n61': 2, 'n62': 3, 'n63': 2, 'n64': 7, 'n65': 4, 'n66': 28, 'n67': 1, 'n68': 2, 'n69': 1, 'n70': 20, 'n71': 3, 'n72': 3, 'n73': 7, 'n74': 20, 'n75': 5, 'n76': 6, 'n77': 2, 'n78': 3, 'n79': 3, 'n80': 24, 'n81': 6, 'n82': 2, 'n83': 105, 'n84': 2, 'n85': 1, 'n86': 2, 'n87': 6, 'n88': 15, 'n89': 1, 'n90': 12, 'n91': 1, 'n92': 60, 'n93': 1, 'n94': 4, 'n95': 1, 'n
# ...

# %%
graph.number_of_nodes()
# Out:
# 1029

# %%
graph.number_of_edges()
# Out:
# 1700

# %%
print(nx.info(graph))
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 1029
# Number of edges: 1700
# Average in degree:   1.6521
# Average out degree:   1.6521

# %%
nx.degree_centrality(graph)
# Out:
# {'n0': 0.05933852140077821,
#  'n1': 0.0048638132295719845,
#  'n2': 0.009727626459143969,
#  'n3': 0.0038910505836575876,
#  'n4': 0.014591439688715954,
#  'n5': 0.0019455252918287938,
#  'n6': 0.14883268482490272,
#  'n7': 0.0019455252918287938,
#  'n8': 0.0038910505836575876,
#  'n9': 0.0029182879377431907,
#  'n10': 0.021400778210116732,
#  'n11': 0.0019455252918287938,
#  'n12': 0.007782101167315175,
#  'n13': 0.0009727626459143969,
#  'n14': 0.033073929961089495,
#  'n15': 0.0009727626459143969,
#  'n16': 0.008754863813229572,
#  'n17': 0.0019455252918287938,
#  'n18': 0.020428015564202335,
#  'n19': 0.0019455252918287938,
#  'n20': 0.011673151750972763,
#  'n21': 0.0038910505836575876,
#  'n22': 0.01264591439688716,
#  'n23': 0.008754863813229572,
#  'n24': 0.0029182879377431907,
#  'n25': 0.0029182879377431907,
#  'n26': 0.016536964980544747,
#  'n27': 0.0009727626459143969,
#  'n28': 0.013618677042801557,
#  'n29': 0.0019455252918287938,
#  'n30': 0.008754863813229572,
# ...

# %%
#UNABLE TO DETERMINE nx.average_shortest_path_length(graph) because graph is not weakly connected

# %%
nx.average_node_connectivity(graph)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-0c6cc21062d7> in <module>
# ----> 1 nx.average_node_connectivity(graph)
#
# /opt/anaconda3/lib/python3.7/site-packages/networkx/algorithms/connectivity/connectivity.py in average_node_connectivity(G, flow_func)
#     410     num, den = 0, 0
#     411     for u, v in iter_func(G, 2):
# --> 412         num += local_node_connectivity(G, u, v, **kwargs)
#     413         den += 1
#     414
#
# /opt/anaconda3/lib/python3.7/site-packages/networkx/algorithms/connectivity/connectivity.py in local_node_connectivity(G, s, t, flow_func, auxiliary, residual, cutoff)
#     207         kwargs['cutoff'] = cutoff
#     208
# --> 209     return nx.maximum_flow_value(H, '%sB' % mapping[s], '%sA' % mapping[t], **kwargs)
#     210
#     211
#
# ...

# %%
nx.node_connectivity(graph)

# %%
graph2 = nx.Graph(graph)
nx.average_clustering(graph2)

# %%
#global efficiency 
ugraph= nx.to_undirected(graph)
nx.global_efficiency(ugraph)

# %%
#local efficiency 

ugraph= nx.to_undirected(graph)
nx.local_efficiency(ugraph)

# %%
graph2 = nx.Graph(graph)
nx.clustering(graph2)

# %%
#modularity will not work because  not implemented for multigraph type

# %%
#smallworld not working despite working for mouse visual cortex 1. 
#output said 'not implemented for multigraph type'

# %%
nx.overall_reciprocity(graph)

# %%
#transitivty not working despite working for mouse visual cortex 1 and 2
#output said 'not implemented for multigraph type'

# %%
#non_randomness not working because not implemented for directed type

# %%
nx.number_of_isolates(graph)

# %%
nx.flow_hierarchy(graph)

# %%
#nx.diameter(graph)=Found infinite path length because the digraph is not strongly connected

# %%
nx.number_weakly_connected_components(graph)

# %%
nx.number_strongly_connected_components(graph)

# %%
#motifs fingerprint
graph.subgraph(graph).copy()

# %%
nx.density(graph)

# %%
#no triangle

# %%
#nodes to percent

# %%
#degree Distribution 
import collections
import matplotlib.pyplot as plt
import networkx as nx

G = nx.gnp_random_graph(100, 0.02)

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)

# %%
#rich_club_coefficient not possible

# %%
#implementing mst
import py.test
run pytest

# %%
pip install tempy

# %%
import numpy.fft as pyfft

# %%
pip install homebrew

# %%
#install dependencies
import cython 
import skimage

# %%
nx.get_node_attributes(graph,'degree')

# %%
df = pd.DataFrame({'Mean Absolute Deviation of a Series': ['Kasthuri']})
df. values. tolist(degree_centrality(graph))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-c65c4cbaecb9> in <module>
#       1 df = pd.DataFrame({'Mean Absolute Deviation of a Series': ['Kasthuri']})
# ----> 2 df. values. tolist(degree_centrality(graph))
#
# NameError: name 'degree_centrality' is not defined

# %%
#Mean Absolute Deviation 
# importing pandas module  
import pandas as pd  
    
# importing numpy module  
import numpy as np  
    
# creating list from degree centrality 
list =[0.05933852140077821,  0.0048638132295719845, 0.009727626459143969, 0.0038910505836575876, 0.014591439688715954, 0.0019455252918287938, 0.14883268482490272, 0.0019455252918287938,
0.0038910505836575876, 0.0029182879377431907, 0.021400778210116732, 0.0019455252918287938, 0.007782101167315175, 0.0009727626459143969, 0.033073929961089495, 0.0009727626459143969, 0.008754863813229572, 0.0019455252918287938, 0.020428015564202335, 0.0019455252918287938, 0.011673151750972763, 0.0038910505836575876, 0.01264591439688716, 0.008754863813229572] 
  
# creating series 
series = pd.Series(list) 
  
# calling .mad() method 
result = series.mad() 
  
# display 
result
# Out:
# 0.01685108625162127

# %%
avg.intensity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1206ab3bec57> in <module>
# ----> 1 avg.intensity
#
# NameError: name 'avg' is not defined
